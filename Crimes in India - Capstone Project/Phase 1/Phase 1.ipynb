# %% [markdown]
# # Capstone Project

# %% [markdown]
# ### (Crimes in India)

# %% [markdown]
# # Phase 1

# %% [markdown]
# ## Data Collection/preparation part.

# %% [markdown]
# # Note:
#
#
#
# ### 1) You can collect data from anywhere (wiki, google, etc) but mention the link from where data is being collected.
#
# ### 2) You can collect the data manually. It's NOT a web scraping task.
#
# ### 3) Data should be collected for the years mentioned in the files. (If you don't find proper data, make your best judgment and fill it, It's absolutely OK. Do not worry about data accuracy)
#
#
#
# ### 1) The population of each state.
#
# ### 2) Literacy Rate in each state
#
# ### 3) Area of each state
#
# ### 4) Collect any other data that helps with your analysis. There is no limitation for anything.
#
# ### 5) Create a new file and keep the above-collected data.

# %% [markdown]
# # Phase 1: Data Collection/Preparation

# %%
# Collect and prepare data
import pandas as pd

# %%
# Corrected code with parentheses around the URL and missing opening parenthesis 
data = pd.read_csv('https://raw.githubusercontent.com/iamajay3737/DataTrained-Education-Projects/main/01_District_wise_crimes_committed_IPC_2001_2012.csv')

# %%
df
# Out:
#             STATE/UT       DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 0     ANDHRA PRADESH       ADILABAD  2001     101                 60
# 1     ANDHRA PRADESH      ANANTAPUR  2001     151                125
# 2     ANDHRA PRADESH       CHITTOOR  2001     101                 57
# 3     ANDHRA PRADESH       CUDDAPAH  2001      80                 53
# 4     ANDHRA PRADESH  EAST GODAVARI  2001      82                 67
# ...              ...            ...   ...     ...                ...
# 9012     LAKSHADWEEP    LAKSHADWEEP  2012       0                  0
# 9013     LAKSHADWEEP          TOTAL  2012       0                  0
# 9014      PUDUCHERRY       KARAIKAL  2012       5                  6
# 9015      PUDUCHERRY     PUDUCHERRY  2012      24                 21
# 9016      PUDUCHERRY          TOTAL  2012      29                 27
#
#       CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# ...

# %%
print(data.head())
# Out:
#          STATE/UT       DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 0  ANDHRA PRADESH       ADILABAD  2001     101                 60
# 1  ANDHRA PRADESH      ANANTAPUR  2001     151                125
# 2  ANDHRA PRADESH       CHITTOOR  2001     101                 57
# 3  ANDHRA PRADESH       CUDDAPAH  2001      80                 53
# 4  ANDHRA PRADESH  EAST GODAVARI  2001      82                 67
#
#    CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 0                                         17    50               0
# 1                                          1    23               0
# 2                                          2    27               0
# 3                                          1    20               0
# 4                                          1    23               0
#
#    OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 0          50                      46  ...     30                1131
# ...

# %%
print(data.tail())
# Out:
#          STATE/UT     DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 9012  LAKSHADWEEP  LAKSHADWEEP  2012       0                  0
# 9013  LAKSHADWEEP        TOTAL  2012       0                  0
# 9014   PUDUCHERRY     KARAIKAL  2012       5                  6
# 9015   PUDUCHERRY   PUDUCHERRY  2012      24                 21
# 9016   PUDUCHERRY        TOTAL  2012      29                 27
#
#       CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 9012                                          0     0               0
# 9013                                          0     0               0
# 9014                                          2     6               0
# 9015                                         10     7               0
# 9016                                         12    13               0
#
#       OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 9012           0                       0  ...      3                   3
# ...

# %%
print(data.columns)
# Out:
# Index(['STATE/UT', 'DISTRICT', 'YEAR', 'MURDER', 'ATTEMPT TO MURDER',
#        'CULPABLE HOMICIDE NOT AMOUNTING TO MURDER', 'RAPE', 'CUSTODIAL RAPE',
#        'OTHER RAPE', 'KIDNAPPING & ABDUCTION',
#        'KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS',
#        'KIDNAPPING AND ABDUCTION OF OTHERS', 'DACOITY',
#        'PREPARATION AND ASSEMBLY FOR DACOITY', 'ROBBERY', 'BURGLARY', 'THEFT',
#        'AUTO THEFT', 'OTHER THEFT', 'RIOTS', 'CRIMINAL BREACH OF TRUST',
#        'CHEATING', 'COUNTERFIETING', 'ARSON', 'HURT/GREVIOUS HURT',
#        'DOWRY DEATHS', 'ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY',
#        'INSULT TO MODESTY OF WOMEN', 'CRUELTY BY HUSBAND OR HIS RELATIVES',
#        'IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES',
#        'CAUSING DEATH BY NEGLIGENCE', 'OTHER IPC CRIMES', 'TOTAL IPC CRIMES'],
#       dtype='object')

# %%
import pandas as pd

# Create a dictionary to store the data
data_dict = {
    'State': [],  # To store the names of states
    'Population': [],  # To store the population of each state
    'Literacy Rate': [],  # To store the literacy rate in each state
    'Area (sq. km)': [],  # To store the area of each state
    'Additional Data 1': [],  # To store additional data 1
    'Additional Data 2': [],  # To store additional data 2
    # Add more keys for additional data as needed
}

# Collect population data (replace with your source)
population_data = {
    'State1': 10000000,
    'State2': 8000000,
    # Add population data for all states
}

# Collect literacy rate data (replace with your source)
literacy_rate_data = {
    'State1': 85.3,
    'State2': 90.5,
    # Add literacy rate data for all states
}

# Collect area data (replace with your source)
area_data = {
    'State1': 50000,
    'State2': 60000,
    # Add area data for all states
}

# Collect additional data 1 (replace with your source)
additional_data_1 = {
    'State1': 0.5,
    'State2': 0.3,
    # Add additional data 1 for all states
}

# Collect additional data 2 (replace with your source)
additional_data_2 = {
    'State1': 'Category A',
    'State2': 'Category B',
    # Add additional data 2 for all states
}

# Populate the data_dict dictionary with collected data
for state in population_data.keys():
    data_dict['State'].append(state)
    data_dict['Population'].append(population_data[state])
    data_dict['Literacy Rate'].append(literacy_rate_data[state])
    data_dict['Area (sq. km)'].append(area_data[state])
    data_dict['Additional Data 1'].append(additional_data_1[state])
    data_dict['Additional Data 2'].append(additional_data_2[state])
    # Add more data as needed

# Create a DataFrame from the data_dict
state_data_df = pd.DataFrame(data_dict)

# Save the DataFrame to a CSV file
state_data_df.to_csv('state_data_with_additional.csv', index=False)

# Print the first few rows of the DataFrame
print(state_data_df.head())
# Out:
#     State  Population  Literacy Rate  Area (sq. km)  Additional Data 1  \
# 0  State1    10000000           85.3          50000                0.5
# 1  State2     8000000           90.5          60000                0.3
#
#   Additional Data 2
# 0        Category A
# 1        Category B

# %%
import pandas as pd

# Load the provided CSV file
data = pd.read_csv('https://raw.githubusercontent.com/iamajay3737/DataTrained-Education-Projects/main/02_01_District_wise_crimes_committed_against_SC_2001_2012.csv')

# Extract unique state names from the data
unique_states = data['STATE/UT'].unique()

# Create a dictionary to store the collected data
collected_data = {
    'State': unique_states,
    'Population': [],
    'Literacy Rate': [],
    'Area (sq. km)': [],
    # Add more keys for additional data as needed
}

# You will need to collect the population, literacy rate, and area data from your chosen sources.
# Since you have not provided specific data sources, I will use placeholder values for demonstration purposes.
# Replace these placeholder values with your actual data.

# Placeholder values for population, literacy rate, and area data (replace with actual data)
population_data = {
    'State1': 10000000,
    'State2': 8000000,
    # Add population data for all states
}

literacy_rate_data = {
    'State1': 85.3,
    'State2': 90.5,
    # Add literacy rate data for all states
}

area_data = {
    'State1': 50000,
    'State2': 60000,
    # Add area data for all states
}

# Populate the collected_data dictionary with the collected or placeholder data
for state in unique_states:
    collected_data['Population'].append(population_data.get(state, 0))  # Replace 0 with actual data if not found
    collected_data['Literacy Rate'].append(literacy_rate_data.get(state, 0))  # Replace 0 with actual data if not found
    collected_data['Area (sq. km)'].append(area_data.get(state, 0))  # Replace 0 with actual data if not found

# Create a DataFrame from the collected data
collected_data_df = pd.DataFrame(collected_data)

# Save the DataFrame to a new CSV file
collected_data_df.to_csv('collected_state_data.csv', index=False)

# Print the first few rows of the DataFrame
print(collected_data_df.head())
# Out:
#                State  Population  Literacy Rate  Area (sq. km)
# 0     ANDHRA PRADESH           0              0              0
# 1  ARUNACHAL PRADESH           0              0              0
# 2              ASSAM           0              0              0
# 3              BIHAR           0              0              0
# 4       CHHATTISGARH           0              0              0

# %%
#Student of DataScience
#Student of DataTrained- Jayram Ishwar Phulwalkar
#Date - 29 -08-2023
#Time - 10:05 am
